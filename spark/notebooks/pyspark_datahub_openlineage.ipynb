# %% [markdown]
# # PySpark → DataHub (openlineage)

# %% [markdown]
# Read from the staging HackerNews RSS tables (`stg_hot_articles`, `stg_newest_articles`) and write
# the combined result into the `hackernews_rss` dataset on BigQuery.

# %% [markdown]
# ### SparkSession Setup

# %%
from pyspark.sql import SparkSession

# %%
spark_jars = ",".join([
    "com.google.cloud.spark:spark-4.0-bigquery:0.44.0",
    "io.openlineage:openlineage-spark_2.13:1.43.0",
])

# %%
spark = (
    SparkSession.builder
    .appName("jupyter-openlineage")
    .master("local[*]")
    .config("spark.jars.packages", spark_jars)
    .config("spark.driver.extraJavaOptions",
        "--add-opens=java.base/java.security=ALL-UNNAMED "
        "--add-opens=java.base/java.lang=ALL-UNNAMED "
        "--add-opens=java.base/java.lang.invoke=ALL-UNNAMED "
        "--add-opens=java.base/java.lang.reflect=ALL-UNNAMED "
        "--add-opens=java.base/java.nio=ALL-UNNAMED "
        "--add-opens=java.base/java.util=ALL-UNNAMED"
    )
    .config('spark.extraListeners', 'io.openlineage.spark.agent.OpenLineageSparkListener')
    .config('spark.openlineage.transport.type', 'http')
    .config('spark.openlineage.transport.url', 'http://localhost:9090')
    .config('spark.openlineage.transport.endpoint', '/openapi/openlineage/api/v1/lineage')
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/Users/iobruno/Vault/data-catalog-labs/spark/.venv/lib/python3.13/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/iobruno/.ivy2.5.2/cache
# The jars for the packages stored in: /Users/iobruno/.ivy2.5.2/jars
# com.google.cloud.spark#spark-4.0-bigquery added as a dependency
# io.openlineage#openlineage-spark_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-8edce058-d8ec-421e-a61a-096e0521dabc;1.0
# 	confs: [default]
# 	found com.google.cloud.spark#spark-4.0-bigquery;0.44.0 in central
# 	found com.google.cloud.spark#spark-bigquery-dsv2-common;0.44.0 in central
# 	found com.google.cloud.spark#spark-bigquery-connector-common;0.44.0 in central
# 	found com.google.cloud.spark#bigquery-connector-common;0.44.0 in central
# 	found com.google.api.grpc#grpc-google-cloud-bigquerystorage-v1;3.16.1 in central
# 	found io.grpc#grpc-api;1.74.0 in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found com.google.errorprone#error_prone_annotations;2.41.0 in central
# 	found io.grpc#grpc-stub;1.74.0 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.24 in central
# 	found io.grpc#grpc-protobuf;1.74.0 in central
# 	found com.google.api.grpc#proto-google-common-protos;2.59.2 in central
# 	found com.google.protobuf#protobuf-java;3.25.8 in central
# 	found com.google.api.grpc#proto-google-cloud-bigquerystorage-v1;3.16.1 in central
# 	found com.google.api#api-common;2.51.2 in central
# 	found com.google.auto.value#auto-value-annotations;1.11.0 in central
# 	found javax.annotation#javax.annotation-api;1.3.2 in central
# 	found com.google.j2objc#j2objc-annotations;3.0.0 in central
# 	found com.google.guava#guava;33.4.8-jre in central
# 	found org.jspecify#jspecify;1.0.0 in central
# 	found com.google.guava#failureaccess;1.0.2 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found org.checkerframework#checker-qual;3.49.0 in central
# 	found com.google.cloud#google-cloud-bigquery;2.54.0 in central
# 	found com.google.cloud#google-cloud-core;2.58.2 in central
# 	found com.google.protobuf#protobuf-java-util;3.25.8 in central
# 	found com.google.api.grpc#proto-google-iam-v1;1.54.2 in central
# 	found org.threeten#threetenbp;1.7.0 in central
# 	found com.google.cloud#google-cloud-core-http;2.58.2 in central
# 	found com.google.api-client#google-api-client;2.7.2 in central
# 	found com.google.oauth-client#google-oauth-client;1.39.0 in central
# 	found com.google.http-client#google-http-client-apache-v2;1.47.1 in central
# 	found com.google.http-client#google-http-client-appengine;1.47.1 in central
# 	found com.google.api#gax-httpjson;2.68.2 in central
# 	found io.opencensus#opencensus-api;0.31.1 in central
# 	found io.opencensus#opencensus-contrib-http-util;0.31.1 in central
# 	found com.google.http-client#google-http-client-gson;1.47.1 in central
# 	found com.google.http-client#google-http-client;1.47.1 in central
# 	found org.apache.httpcomponents#httpclient;4.5.14 in central
# 	found org.apache.httpcomponents#httpcore;4.4.16 in central
# 	found io.grpc#grpc-context;1.74.0 in central
# 	found org.checkerframework#checker-compat-qual;2.5.6 in central
# 	found com.google.auth#google-auth-library-credentials;1.37.1 in central
# 	found com.google.auth#google-auth-library-oauth2-http;1.37.1 in central
# 	found com.google.apis#google-api-services-bigquery;v2-rev20250706-2.0.0 in central
# 	found com.google.api#gax;2.68.2 in central
# 	found org.threeten#threeten-extra;1.8.0 in central
# 	found com.google.cloud#google-cloud-bigquerystorage;3.16.1 in central
# 	found io.grpc#grpc-util;1.74.0 in central
# 	found io.grpc#grpc-core;1.74.0 in central
# 	found com.google.auto.value#auto-value;1.11.0 in central
# 	found com.google.api.grpc#proto-google-cloud-bigquerystorage-v1beta;3.16.1 in central
# 	found com.google.api.grpc#proto-google-cloud-bigquerystorage-v1alpha;3.16.1 in central
# 	found com.google.api#gax-grpc;2.68.2 in central
# 	found io.grpc#grpc-inprocess;1.74.0 in central
# 	found io.grpc#grpc-alts;1.74.0 in central
# 	found io.grpc#grpc-grpclb;1.74.0 in central
# 	found org.conscrypt#conscrypt-openjdk-uber;2.5.2 in central
# 	found io.grpc#grpc-auth;1.74.0 in central
# 	found org.json#json;20231013 in central
# 	found io.opentelemetry#opentelemetry-api;1.47.0 in central
# 	found io.opentelemetry#opentelemetry-context;1.47.0 in central
# 	found commons-codec#commons-codec;1.19.0 in central
# 	found io.grpc#grpc-netty-shaded;1.74.0 in central
# 	found org.apache.arrow#arrow-vector;18.3.0 in central
# 	found org.apache.arrow#arrow-format;18.3.0 in central
# 	found org.apache.arrow#arrow-memory-core;18.3.0 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.19.2 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.19.2 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.19.2 in central
# 	found com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.19.2 in central
# 	found com.google.flatbuffers#flatbuffers-java;24.3.25 in central
# 	found org.slf4j#slf4j-api;2.0.13 in central
# 	found com.google.inject#guice;5.1.0 in central
# 	found javax.inject#javax.inject;1 in central
# 	found aopalliance#aopalliance;1.0 in central
# 	found io.grpc#grpc-netty;1.74.0 in central
# 	found io.netty#netty-codec-http2;4.2.7.Final in central
# 	found io.netty#netty-common;4.2.7.Final in central
# 	found io.netty#netty-buffer;4.2.7.Final in central
# 	found io.netty#netty-transport;4.2.7.Final in central
# 	found io.netty#netty-resolver;4.2.7.Final in central
# 	found io.netty#netty-codec-base;4.2.7.Final in central
# 	found io.netty#netty-handler;4.2.7.Final in central
# 	found io.netty#netty-transport-native-unix-common;4.2.7.Final in central
# 	found io.netty#netty-codec-http;4.2.7.Final in central
# 	found io.netty#netty-codec-compression;4.2.7.Final in central
# 	found org.apache.arrow#arrow-memory-netty;18.3.0 in central
# 	found org.apache.arrow#arrow-memory-netty-buffer-patch;18.3.0 in central
# 	found com.google.code.gson#gson;2.9.1 in central
# 	found io.openlineage#spark-extension-interfaces;1.37.0 in central
# 	found org.apache.beam#beam-sdks-java-io-hadoop-common;2.43.0 in central
# 	found org.apache.arrow#arrow-compression;18.3.0 in central
# 	found org.apache.commons#commons-compress;1.27.1 in central
# 	found commons-io#commons-io;2.18.0 in central
# 	found org.apache.commons#commons-lang3;3.18.0 in central
# 	found com.github.luben#zstd-jni;1.4.9-1 in central
# 	found io.grpc#grpc-protobuf-lite;1.74.0 in central
# 	found com.google.android#annotations;4.1.1.4 in central
# 	found io.perfmark#perfmark-api;0.27.0 in central
# 	found io.grpc#grpc-googleapis;1.74.0 in central
# 	found io.netty#netty-handler-proxy;4.2.7.Final in central
# 	found io.netty#netty-codec-socks;4.2.7.Final in central
# 	found io.netty#netty-tcnative-boringssl-static;2.0.74.Final in central
# 	found io.netty#netty-tcnative-classes;2.0.74.Final in central
# 	found io.openlineage#openlineage-spark_2.13;1.43.0 in central
# :: resolution report :: resolve 1190ms :: artifacts dl 25ms
# 	:: modules in use:
# 	aopalliance#aopalliance;1.0 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.19.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.19.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.19.2 from central in [default]
# 	com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.19.2 from central in [default]
# 	com.github.luben#zstd-jni;1.4.9-1 from central in [default]
# 	com.google.android#annotations;4.1.1.4 from central in [default]
# 	com.google.api#api-common;2.51.2 from central in [default]
# 	com.google.api#gax;2.68.2 from central in [default]
# 	com.google.api#gax-grpc;2.68.2 from central in [default]
# 	com.google.api#gax-httpjson;2.68.2 from central in [default]
# 	com.google.api-client#google-api-client;2.7.2 from central in [default]
# 	com.google.api.grpc#grpc-google-cloud-bigquerystorage-v1;3.16.1 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-bigquerystorage-v1;3.16.1 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-bigquerystorage-v1alpha;3.16.1 from central in [default]
# 	com.google.api.grpc#proto-google-cloud-bigquerystorage-v1beta;3.16.1 from central in [default]
# 	com.google.api.grpc#proto-google-common-protos;2.59.2 from central in [default]
# 	com.google.api.grpc#proto-google-iam-v1;1.54.2 from central in [default]
# 	com.google.apis#google-api-services-bigquery;v2-rev20250706-2.0.0 from central in [default]
# 	com.google.auth#google-auth-library-credentials;1.37.1 from central in [default]
# 	com.google.auth#google-auth-library-oauth2-http;1.37.1 from central in [default]
# 	com.google.auto.value#auto-value;1.11.0 from central in [default]
# 	com.google.auto.value#auto-value-annotations;1.11.0 from central in [default]
# 	com.google.cloud#google-cloud-bigquery;2.54.0 from central in [default]
# 	com.google.cloud#google-cloud-bigquerystorage;3.16.1 from central in [default]
# 	com.google.cloud#google-cloud-core;2.58.2 from central in [default]
# 	com.google.cloud#google-cloud-core-http;2.58.2 from central in [default]
# 	com.google.cloud.spark#bigquery-connector-common;0.44.0 from central in [default]
# 	com.google.cloud.spark#spark-4.0-bigquery;0.44.0 from central in [default]
# 	com.google.cloud.spark#spark-bigquery-connector-common;0.44.0 from central in [default]
# 	com.google.cloud.spark#spark-bigquery-dsv2-common;0.44.0 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.9.1 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.41.0 from central in [default]
# 	com.google.flatbuffers#flatbuffers-java;24.3.25 from central in [default]
# 	com.google.guava#failureaccess;1.0.2 from central in [default]
# 	com.google.guava#guava;33.4.8-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.http-client#google-http-client;1.47.1 from central in [default]
# 	com.google.http-client#google-http-client-apache-v2;1.47.1 from central in [default]
# 	com.google.http-client#google-http-client-appengine;1.47.1 from central in [default]
# 	com.google.http-client#google-http-client-gson;1.47.1 from central in [default]
# 	com.google.inject#guice;5.1.0 from central in [default]
# 	com.google.j2objc#j2objc-annotations;3.0.0 from central in [default]
# 	com.google.oauth-client#google-oauth-client;1.39.0 from central in [default]
# 	com.google.protobuf#protobuf-java;3.25.8 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.25.8 from central in [default]
# 	commons-codec#commons-codec;1.19.0 from central in [default]
# 	commons-io#commons-io;2.18.0 from central in [default]
# 	io.grpc#grpc-alts;1.74.0 from central in [default]
# 	io.grpc#grpc-api;1.74.0 from central in [default]
# 	io.grpc#grpc-auth;1.74.0 from central in [default]
# 	io.grpc#grpc-context;1.74.0 from central in [default]
# 	io.grpc#grpc-core;1.74.0 from central in [default]
# 	io.grpc#grpc-googleapis;1.74.0 from central in [default]
# 	io.grpc#grpc-grpclb;1.74.0 from central in [default]
# 	io.grpc#grpc-inprocess;1.74.0 from central in [default]
# 	io.grpc#grpc-netty;1.74.0 from central in [default]
# 	io.grpc#grpc-netty-shaded;1.74.0 from central in [default]
# 	io.grpc#grpc-protobuf;1.74.0 from central in [default]
# 	io.grpc#grpc-protobuf-lite;1.74.0 from central in [default]
# 	io.grpc#grpc-stub;1.74.0 from central in [default]
# 	io.grpc#grpc-util;1.74.0 from central in [default]
# 	io.netty#netty-buffer;4.2.7.Final from central in [default]
# 	io.netty#netty-codec-base;4.2.7.Final from central in [default]
# 	io.netty#netty-codec-compression;4.2.7.Final from central in [default]
# 	io.netty#netty-codec-http;4.2.7.Final from central in [default]
# 	io.netty#netty-codec-http2;4.2.7.Final from central in [default]
# 	io.netty#netty-codec-socks;4.2.7.Final from central in [default]
# 	io.netty#netty-common;4.2.7.Final from central in [default]
# 	io.netty#netty-handler;4.2.7.Final from central in [default]
# 	io.netty#netty-handler-proxy;4.2.7.Final from central in [default]
# 	io.netty#netty-resolver;4.2.7.Final from central in [default]
# 	io.netty#netty-tcnative-boringssl-static;2.0.74.Final from central in [default]
# 	io.netty#netty-tcnative-classes;2.0.74.Final from central in [default]
# 	io.netty#netty-transport;4.2.7.Final from central in [default]
# 	io.netty#netty-transport-native-unix-common;4.2.7.Final from central in [default]
# 	io.opencensus#opencensus-api;0.31.1 from central in [default]
# 	io.opencensus#opencensus-contrib-http-util;0.31.1 from central in [default]
# 	io.openlineage#openlineage-spark_2.13;1.43.0 from central in [default]
# 	io.openlineage#spark-extension-interfaces;1.37.0 from central in [default]
# 	io.opentelemetry#opentelemetry-api;1.47.0 from central in [default]
# 	io.opentelemetry#opentelemetry-context;1.47.0 from central in [default]
# 	io.perfmark#perfmark-api;0.27.0 from central in [default]
# 	javax.annotation#javax.annotation-api;1.3.2 from central in [default]
# 	javax.inject#javax.inject;1 from central in [default]
# 	org.apache.arrow#arrow-compression;18.3.0 from central in [default]
# 	org.apache.arrow#arrow-format;18.3.0 from central in [default]
# 	org.apache.arrow#arrow-memory-core;18.3.0 from central in [default]
# 	org.apache.arrow#arrow-memory-netty;18.3.0 from central in [default]
# 	org.apache.arrow#arrow-memory-netty-buffer-patch;18.3.0 from central in [default]
# 	org.apache.arrow#arrow-vector;18.3.0 from central in [default]
# 	org.apache.beam#beam-sdks-java-io-hadoop-common;2.43.0 from central in [default]
# 	org.apache.commons#commons-compress;1.27.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.18.0 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.14 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.16 from central in [default]
# 	org.checkerframework#checker-compat-qual;2.5.6 from central in [default]
# 	org.checkerframework#checker-qual;3.49.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.24 from central in [default]
# 	org.conscrypt#conscrypt-openjdk-uber;2.5.2 from central in [default]
# 	org.json#json;20231013 from central in [default]
# 	org.jspecify#jspecify;1.0.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.13 from central in [default]
# 	org.threeten#threeten-extra;1.8.0 from central in [default]
# 	org.threeten#threetenbp;1.7.0 from central in [default]
# 	:: evicted modules:
# 	com.google.code.gson#gson;2.12.1 by [com.google.code.gson#gson;2.9.1] in [default]
# 	com.google.flatbuffers#flatbuffers-java;25.2.10 by [com.google.flatbuffers#flatbuffers-java;24.3.25] in [default]
# 	org.slf4j#slf4j-api;2.0.17 by [org.slf4j#slf4j-api;2.0.13] in [default]
# 	org.checkerframework#checker-qual;3.10.0 by [org.checkerframework#checker-qual;3.49.0] in [default]
# 	com.google.guava#failureaccess;1.0.3 by [com.google.guava#failureaccess;1.0.2] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  111  |   0   |   0   |   5   ||  106  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-8edce058-d8ec-421e-a61a-096e0521dabc
# 	confs: [default]
# 	0 artifacts copied, 106 already retrieved (0kB/10ms)
# 26/02/13 04:18:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/13 04:19:00 WARN SparkOpenLineageExtensionVisitorWrapper: An illegal reflective access operation will occur when using the openlineage-spark integration with a Spark connector that implements spark-openlineage extension interfaces.
# This issue arises when the openlineage-spark integration and the Spark connector are loaded using different classloaders. For example, if one library is loaded using the --jars parameter while the other is placed in the /usr/lib/spark/jars directory.
# In this case, the OpenLineageExtensionProvider class will only be accessible to the class loader that loaded the openlineage-spark integration. If the other class loader attempts to access this class, it will trigger an illegal reflective access operation.
# To prevent this, ensure that both the openlineage-spark integration and the Spark connector are loaded using the same class loader. This can be achieved by:
# 1. Placing both libraries in the /usr/lib/spark/jars directory, or
# 2. Loading both libraries through the --jars parameter.

# %% [markdown]
# ### Read Staging Tables

# %%
GCP_PROJECT = "iobruno-gcp-labs"
STG_DATASET = "stg_hackernews_rss"

df_hot = (
    spark.read
    .format("bigquery")
    .option("table", f"{GCP_PROJECT}.{STG_DATASET}.stg_hot_articles")
    .option("viewsEnabled", "true")
    .option("materializationDataset", STG_DATASET)
    .load()
)

df_hot.printSchema()
df_hot.show(5, truncate=False)
# Out:
# root
#  |-- uid: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- redirect_url: string (nullable = true)
#  |-- published_at: timestamp (nullable = true)
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+
# |uid                             |title                                                                           |username   |url                                          |redirect_url                                                                                                           |published_at       |
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+
# |7b54e42263906dd156b7743931038f1e|Byte magazine artist Robert Tinney, who illustrated the birth of PCs, dies at 78|rbanffy    |https://news.ycombinator.com/item?id=46987425|https://arstechnica.com/gadgets/2026/02/byte-magazine-artist-robert-tinney-who-illustrated-the-birth-of-pcs-dies-at-78/|2026-02-12 08:26:15|
# |8b9e92677d95ad04102e942df99db7ba|Carl Sagan's Baloney Detection Kit: Tools for Thinking Critically (2025)        |nobody9999 |https://news.ycombinator.com/item?id=46985609|https://www.openculture.com/2025/09/the-carl-sagan-baloney-detection-kit.html                                          |2026-02-12 03:54:39|
# |7f8b2979cc85a656fccecee2abb7d382|AI agent opens a PR write a blogpost to shames the maintainer who closes it     |wrxd       |https://news.ycombinator.com/item?id=46987559|https://github.com/matplotlib/matplotlib/pull/31132                                                                    |2026-02-12 08:46:01|
# |518dc77d958fe73d668c93d6c2892d7c|NetNewsWire Turns 23                                                            |robin_reala|https://news.ycombinator.com/item?id=46978490|https://netnewswire.blog/2026/02/11/netnewswire-turns.html                                                             |2026-02-11 15:06:11|
# |b2718d93acac8f11c256e0f756a0e70a|How to make a living as an artist                                               |gwintrob   |https://news.ycombinator.com/item?id=46984735|https://essays.fnnch.com/make-a-living                                                                                 |2026-02-12 00:56:26|
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+
# only showing top 5 rows

# %%
df_newest = (
    spark.read
    .format("bigquery")
    .option("table", f"{GCP_PROJECT}.{STG_DATASET}.stg_newest_articles")
    .option("viewsEnabled", "true")
    .option("materializationDataset", STG_DATASET)
    .load()
)

df_newest.printSchema()
df_newest.show(5, truncate=False)
# Out:
# root
#  |-- uid: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- redirect_url: string (nullable = true)
#  |-- published_at: timestamp (nullable = true)
#
# +--------------------------------+-------------------------------------------------------------------------------+------------+---------------------------------------------+---------------------------------------------------------------------------------------------------------+-------------------+
# |uid                             |title                                                                          |username    |url                                          |redirect_url                                                                                             |published_at       |
# +--------------------------------+-------------------------------------------------------------------------------+------------+---------------------------------------------+---------------------------------------------------------------------------------------------------------+-------------------+
# |2b177f05631c0419d3df8e6fe106512c|Claude prefers JSON over Markdown                                              |angelmm     |https://news.ycombinator.com/item?id=46990230|https://capsule.endor.dev?gist=40cb2bb9e073fadd772c92232c6016c8                                          |2026-02-12 12:45:00|
# |e552654b1a018da0e9152366afcacf1b|ChargePoint data shows a new EV bottleneck forming                             |toomuchtodo |https://news.ycombinator.com/item?id=46990233|https://electrek.co/2026/02/11/chargepoint-data-shows-a-new-ev-bottleneck-forming/                       |2026-02-12 12:45:07|
# |b39acf5c9a753e731f86e6ed6457a697|The Future Of GPU Infrastructure (renting > owning infra) [video]              |alecco      |https://news.ycombinator.com/item?id=46990254|https://www.youtube.com/watch?v=AsQwwvvRlW4                                                              |2026-02-12 12:47:02|
# |fa91ca1d93d92fb13b06a43810124697|Diablo II: Resurrected – Reign of the Warlock                                  |reconnecting|https://news.ycombinator.com/item?id=46990258|https://diablo2.blizzard.com/en-us/                                                                      |2026-02-12 12:47:13|
# |00386638c3940c7e7b7ecd67c8bf8e3e|ByteDance's AI model can generate clips based on text, images, audio, and video|speckx      |https://news.ycombinator.com/item?id=46990276|https://www.theverge.com/ai-artificial-intelligence/877931/bytedance-seedance-2-video-generator-ai-launch|2026-02-12 12:48:20|
# +--------------------------------+-------------------------------------------------------------------------------+------------+---------------------------------------------+---------------------------------------------------------------------------------------------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ### Combine Articles

# %%
from pyspark.sql.functions import lit

df_hot_tagged = df_hot.withColumn("source_feed", lit("hot"))
df_newest_tagged = df_newest.withColumn("source_feed", lit("newest"))

df_articles = df_hot_tagged.unionByName(df_newest_tagged)

print(f"Total articles: {df_articles.count()}")
df_articles.show(10, truncate=False)
# Out:
# Total articles: 40
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+-----------+
# |uid                             |title                                                                           |username   |url                                          |redirect_url                                                                                                           |published_at       |source_feed|
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+-----------+
# |7b54e42263906dd156b7743931038f1e|Byte magazine artist Robert Tinney, who illustrated the birth of PCs, dies at 78|rbanffy    |https://news.ycombinator.com/item?id=46987425|https://arstechnica.com/gadgets/2026/02/byte-magazine-artist-robert-tinney-who-illustrated-the-birth-of-pcs-dies-at-78/|2026-02-12 08:26:15|hot        |
# |8b9e92677d95ad04102e942df99db7ba|Carl Sagan's Baloney Detection Kit: Tools for Thinking Critically (2025)        |nobody9999 |https://news.ycombinator.com/item?id=46985609|https://www.openculture.com/2025/09/the-carl-sagan-baloney-detection-kit.html                                          |2026-02-12 03:54:39|hot        |
# |7f8b2979cc85a656fccecee2abb7d382|AI agent opens a PR write a blogpost to shames the maintainer who closes it     |wrxd       |https://news.ycombinator.com/item?id=46987559|https://github.com/matplotlib/matplotlib/pull/31132                                                                    |2026-02-12 08:46:01|hot        |
# |518dc77d958fe73d668c93d6c2892d7c|NetNewsWire Turns 23                                                            |robin_reala|https://news.ycombinator.com/item?id=46978490|https://netnewswire.blog/2026/02/11/netnewswire-turns.html                                                             |2026-02-11 15:06:11|hot        |
# |b2718d93acac8f11c256e0f756a0e70a|How to make a living as an artist                                               |gwintrob   |https://news.ycombinator.com/item?id=46984735|https://essays.fnnch.com/make-a-living                                                                                 |2026-02-12 00:56:26|hot        |
# |ba1960e947757dc7cc1137da3f683f62|Hologram v0.7.0: Milestone release for Elixir-to-JavaScript porting initiative  |bartblast  |https://news.ycombinator.com/item?id=46982943|https://hologram.page/blog/porting-initiative-delivers-hologram-v0-7-0                                                 |2026-02-11 20:54:59|hot        |
# |dbf3e45493ca74ce8bb183c3784ead75|Apple patches decade-old iOS zero-day, possibly exploited by commercial spyware |beardyw    |https://news.ycombinator.com/item?id=46989107|https://www.theregister.com/2026/02/12/apple_ios_263/                                                                  |2026-02-12 11:16:10|hot        |
# |b224e6a483fc591c22d42421d08006de|Run Pebble OS in Browser via WASM                                               |goranmoomin|https://news.ycombinator.com/item?id=46988462|https://ericmigi.github.io/pebble-qemu-wasm/                                                                           |2026-02-12 10:16:11|hot        |
# |1ce6470bad0389b0efbcaa2cbc7c143e|Show HN: Geo Racers – Race from London to Tokyo on a single bus pass            |pattle     |https://news.ycombinator.com/item?id=46987038|https://geo-racers.com/                                                                                                |2026-02-12 07:27:50|hot        |
# |e7c3b2edb53318bc3884624dc5c650a9|Discord/Twitch/Snapchat age verification bypass                                 |JustSkyfall|https://news.ycombinator.com/item?id=46982421|https://age-verifier.kibty.town/                                                                                       |2026-02-11 19:56:41|hot        |
# +--------------------------------+--------------------------------------------------------------------------------+-----------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------+-------------------+-----------+
# only showing top 10 rows

# %% [markdown]
# ### Write to BigQuery

# %%
TARGET_DATASET = "hackernews_rss"
TARGET_TABLE = f"{GCP_PROJECT}.{TARGET_DATASET}.articles_spark"

(
    df_articles.write
    .format("bigquery")
    .option("table", TARGET_TABLE)
    .option("writeMethod", "direct")
    .mode("overwrite")
    .save()
)

print(f"Written to {TARGET_TABLE}")
# Out:
# Written to iobruno-gcp-labs.hackernews_rss.articles_spark

# %% [markdown]
# ### Cleanup

# %%
spark.stop()
